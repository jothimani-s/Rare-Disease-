# %% [markdown]
# # EMBKGF Phase 1
# Dataset Integration

# %%
from pathlib import Path
import pandas as pd
DATA_DIR=Path('../datasets')
print(DATA_DIR.resolve())

# %%
expected=['ClinVar','HPO','Orphanet','OMIM','DisGeNET']
for d in expected:
    print(d,(DATA_DIR/d).exists())

# %%
print('Add dataset loading and preprocessing here.')
