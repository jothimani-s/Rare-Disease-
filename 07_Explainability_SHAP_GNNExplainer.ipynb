# %% [markdown]
# # 07 Explainability using SHAP and GNNExplainer

# %%
import torch
import shap
from src.explainability import ExplainabilityModule

# %% [markdown]
# ## Load trained prediction model

# %%
# model.load_state_dict(torch.load('disease_predictor.pt'))
print("Load trained predictor here")

# %% [markdown]
# ## Generate SHAP explanations

# %%
background=torch.randn(100,64)
samples=torch.randn(20,64)

# exp=ExplainabilityModule(model)
# shap_values=exp.shap_explainer(background,samples)

# %% [markdown]
# ## GNNExplainer

# %%
# from torch_geometric.explain import Explainer,GNNExplainer
# Configure GNNExplainer here

# %% [markdown]
# ## Attention Visualization

# %%
# exp.attention_heatmap(attention_weights)

# %% [markdown]
# ## Feature Importance

# %%
# exp.feature_importance_plot(shap_values,samples)
