# %% [markdown]
# # 04 R-GCN Model
# Research implementation scaffold.

# %%
import torch
from torch_geometric.data import Data
from src.rgcn import RGCN

# %% [markdown]
# ## Prepare graph tensors

# %%
# edge_index = ...
# edge_type = ...
num_nodes=100
num_relations=5

# %% [markdown]
# ## Initialize model

# %%
model=RGCN(num_nodes,num_relations)
optimizer=torch.optim.Adam(model.parameters(),lr=1e-3)
print(model)

# %% [markdown]
# ## Training loop

# %%
# Replace with actual labels and graph
print("Implement node classification training here.")

# %% [markdown]
# ## Save model

# %%
# torch.save(model.state_dict(),'rgcn_model.pt')
