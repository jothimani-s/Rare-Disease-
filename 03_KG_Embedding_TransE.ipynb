# %% [markdown]
# # 03 KG Embedding (TransE)

# %%
import torch
import pandas as pd
from src.embedding import TransE

# %%
print('Load triples and build entity/relation indices')

# %%
print('Train TransE model here')
