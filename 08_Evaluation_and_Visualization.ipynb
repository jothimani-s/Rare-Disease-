# %% [markdown]
# # 08 Evaluation and Visualization

# %%
import numpy as np
from src.metrics import evaluate
from src.visualization import plot_loss,plot_confusion

# %% [markdown]
# ## Example predictions

# %%
y_true=np.random.randint(0,3,200)
y_pred=np.random.randint(0,3,200)
results=evaluate(y_true,y_pred)
print(results)

# %% [markdown]
# ## Training loss visualization

# %%
losses=[1.2,0.9,0.7,0.55,0.42]
plot_loss(losses)

# %% [markdown]
# ## Confusion matrix

# %%
plot_confusion(results['confusion_matrix'])

# %% [markdown]
# ## Placeholder cells

# %%
# ROC Curve
# Precision-Recall Curve
# Ablation Study
# Graph Statistics
# Export publication-quality figures
