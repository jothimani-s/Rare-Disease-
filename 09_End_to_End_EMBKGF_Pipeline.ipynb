# %% [markdown]
# # 09 End-to-End EMBKGF Pipeline

# %% [markdown]
# This notebook integrates all previous phases into a single workflow.

# %%
from src.config import CONFIG
from src.utils import print_banner

print_banner("EMBKGF Pipeline")
print(CONFIG)

# %% [markdown]
# ## Step 1 - Dataset Integration

# %%
# Run Notebook 01

# %% [markdown]
# ## Step 2 - Knowledge Graph Construction

# %%
# Run Notebook 02

# %% [markdown]
# ## Step 3 - KG Embedding (TransE)

# %%
# Run Notebook 03

# %% [markdown]
# ## Step 4 - R-GCN

# %%
# Run Notebook 04

# %% [markdown]
# ## Step 5 - ABAN

# %%
# Run Notebook 05

# %% [markdown]
# ## Step 6 - Disease Prediction

# %%
# Run Notebook 06

# %% [markdown]
# ## Step 7 - Explainability

# %%
# Run Notebook 07

# %% [markdown]
# ## Step 8 - Evaluation

# %%
# Run Notebook 08

# %% [markdown]
# ## Step 9 - Export Results

# %%
print("Saving trained models...")
print("Saving GraphML...")
print("Saving embeddings...")
print("Saving figures...")
print("Done.")
